# %%
import pandas as pd
import numpy as np

# %%
housing=pd.read_csv('train.csv')
housing.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# Create a test set

from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(housing, test_size=0.2, random_state=27) # random_state: reproducibility


print(housing.shape)
print(train_set.shape)
print(test_set.shape)
# Out:
# (1460, 81)
# (1168, 81)
# (292, 81)

# %%
housing = train_set.copy()

# %%
housing.head(1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1128  1129          60       RL         59.0    11796   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1128         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1128      7   2007        WD         Normal     215000
#
# [1 rows x 81 columns]

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')

# %%
housing_num = housing.drop('SaleCondition', axis=1)

# %%
housing_num.head(1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1128  1129          60       RL         59.0    11796   Pave   NaN      IR1
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 1128         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#      MiscVal MoSold  YrSold  SaleType  SalePrice
# 1128       0      7    2007        WD     215000
#
# [1 rows x 80 columns]

# %%
# Get the rows which have atleast one column with null values
housing_num[housing_num.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1128  1129          60       RL         59.0    11796   Pave   NaN      IR1
# 749    750          50       RL         50.0     8405   Pave   NaN      Reg
# 1313  1314          60       RL        108.0    14774   Pave   NaN      IR1
# 1006  1007          20       RL          NaN    12155   Pave   NaN      IR3
# 590    591          60       RL         64.0     8320   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1048  1049          20       RL        100.0    21750   Pave   NaN      Reg
# 1317  1318         120       FV         47.0     4230   Pave  Pave      Reg
# 752    753          20       RL         79.0     9236   Pave   NaN      IR1
# 543    544         120       RH         34.0     4058   Pave   NaN      Reg
# 1043  1044          60       RL         86.0    11839   Pave   NaN      Reg
#
#      LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence  \
# 1128         Lvl    AllPub  ...           0        0    NaN    NaN
# 749          Lvl    AllPub  ...           0        0    NaN    NaN
# 1313         Lvl    AllPub  ...           0        0    NaN    NaN
# 1006         Lvl    AllPub  ...         147        0    NaN    NaN
# 590          Lvl    AllPub  ...           0        0    NaN    NaN
# ...          ...       ...  ...         ...      ...    ...    ...
# 1048         Lvl    AllPub  ...           0        0    NaN  GdPrv
# 1317         Lvl    AllPub  ...           0        0    NaN    NaN
# 752          Lvl    AllPub  ...           0        0    NaN    NaN
# 543          Lvl    AllPub  ...           0        0    NaN    NaN
# 1043         Lvl    AllPub  ...           0        0    NaN    NaN
#
#      MiscFeature MiscVal MoSold  YrSold  SaleType  SalePrice
# 1128         NaN       0      7    2007        WD     215000
# 749          NaN       0      4    2009        WD      98000
# 1313         NaN       0      5    2010        WD     333168
# 1006         NaN       0      3    2007        WD     163500
# 590          NaN       0      9    2008        WD     185900
# ...          ...     ...    ...     ...       ...        ...
# 1048         NaN       0     11    2009        WD     115000
# 1317         NaN       0      4    2007       New     208900
# 752          NaN       0      7    2006        WD     217000
# 543          NaN       0      6    2007        WD     133000
# 1043         NaN       0      5    2008        WD     262280
#
# [1168 rows x 80 columns]
